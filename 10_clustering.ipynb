# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_blobs

# %%
from sklearn.cluster import KMeans

# %%
X,y = make_blobs(n_samples = 300, centers = 3, cluster_std = 0.6)

# %%
plt.scatter(X[:,0],X[:,1],c = 'blue')

# %%
inertia = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# %%
plt.plot(inertia)

# %%
kmeans = KMeans(n_clusters = 3)
kmeans.fit(X)
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %%
plt.scatter(X[:,0],X[:,1],c = labels, cmap = 'viridis')
plt.scatter(centroids[:,0],centroids[:,1],c = 'red', cmap = 'viridis')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_2016\519263359.py:2: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(centroids[:,0],centroids[:,1],c = 'red', cmap = 'viridis')

# %%
# For datasets

# %%
data = pd.read_csv('Mall_Customers.csv')
data
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.drop(columns=['CustomerID'],inplace = True)
data['Gender'] = np.where(data['Gender']=='Male',1,0)

# %%
plt.scatter(data['Annual Income (k$)'], data['Spending Score (1-100)'])

# %%
inertia = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(data)
    inertia.append(kmeans.inertia_)
plt.plot(inertia)

# %%
kmeans = KMeans(n_clusters = 5)
kmeans.fit(data)
# Out:
# KMeans(n_clusters=5)

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_
plt.scatter(data['Annual Income (k$)'], data['Spending Score (1-100)'], c = labels, cmap = 'viridis')
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_2016\2089479276.py:4: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(centroids[:,0],centroids[:,1],c = 'red', cmap = 'viridis')
